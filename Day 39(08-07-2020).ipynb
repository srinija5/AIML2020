# %% [markdown]
# [deep learning](https://docs.google.com/document/d/1BtHh9DQZKM1QIS43iFlINvlMswEv1yukrh8-GiKQFuU/edit#)

# %% [markdown]
# [neural network playground](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=xor&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=3,2&seed=0.04013&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=true&ySquared=true&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = plt.imread("C:/Users/SOWMYA/Desktop/SUMMER INTERNSHIP AIML/color.jpg")
print(img.shape)
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
# image with one direction
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,:125,:])
