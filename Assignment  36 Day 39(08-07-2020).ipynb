# %% [markdown]
# # CSE - 221710310015 - ETTOM.SRINJA

# %% [markdown]
# Read an image(which contains different objects) using matplotlib and check the shape of the image?<br>
# Display the image?<br>
# Identify the different objects in the image?<br>
# Use slicing to get the objects and display them?<br>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
! pip install pillow

# %%
img=plt.imread("C:/Users/Srinaja/Desktop/AIML/a3.jpeg")
print(img.shape)
# Out:
# (1151, 1080, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,0:1000])

# %%
plt.imshow(img[:400,:1000])

# %%
plt.imshow(img[200:300,550:750])

# %%
plt.imshow(img[450:900,250:1000])
