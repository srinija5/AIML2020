# %% [markdown]
# ### CSE - 221710310015 - ETTOM.SRINIJA

# %% [markdown]
# #### IMPORTING THE REQUIRED PACKAGES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips= sns.load_dataset("tips")
#seaborn has some inbuilt datasets aand tips is one of them
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Plots using:
# 1. Pandas
# 2. Matplotlib
# 3. Seaborn

# %%
tips['total_bill'].hist()
#without using plot
#x axis shows total bill.
#y axis shows number of customers

# %%
plt.hist(tips['total_bill'])
#with using plot
#x axis shows total bill.
#y axis shows number of customers
#below arrays represent 3.07 total bill ->7 customers
#7.884 bill ->42 customers
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(tips['total_bill'],bins=5)
#bins is the no.of parts it takes to divide the set. 
# it divides the st into bin+1 parts
# Out:
# (array([ 49., 119.,  50.,  19.,   7.]),
#  array([ 3.07 , 12.618, 22.166, 31.714, 41.262, 50.81 ]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# ## Seaborn Package:

# %% [markdown]
# ### Relational Plot:

# %%
sns.relplot("total_bill","tip",data= tips)
#relplot-> shows the relation between columns and is similar tp scatter plot but in sns

# %%
sns.relplot("total_bill","tip",data= tips,hue="smoker")
#hue->for differentiating between options of specific column

# %%
sns.relplot("total_bill","tip",data= tips,col="smoker")
#col--> Separate graph for smoker yes and smoker no

# %%
sns.relplot("total_bill","tip",data= tips,hue="smoker",col="sex")

# %%
sns.__version__
# Out:
# '0.9.0'

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
sns.relplot("total_bill","tip",data= tips,hue="smoker",kind="line")

# %%
sns.relplot("total_bill","tip",data= tips,kind="line")

# %%
sns.relplot("total_bill","tip",data= tips,kind="scatter")

# %%
sns.scatterplot("total_bill","tip",data= tips)

# %% [markdown]
# ### Categorical Plot:

# %%
sns.catplot("day","tip",data= tips)

# %%
sns.catplot("day","tip",data= tips,kind='swarm')
#swarm-> gives more detailed points for some points

# %%
sns.catplot("day","tip",data= tips,kind='swarm',hue="smoker")

# %%
sns.catplot("day","tip",data= tips,kind='swarm',hue="smoker",col="sex")
#hue->differentiates between categories of columns
#col->presents separate graphs for each categories

# %%
sns.catplot("day","total_bill",data= tips,kind='box',hue="sex")

# %% [markdown]
# ### Count (kind) :

# %%
sns.catplot("day",data=tips,kind='count')

# %%
sns.catplot("day",data=tips,kind='count',hue="smoker")

# %% [markdown]
# ### Box Plot:

# %%
sns.boxplot(tips['tip'])

# %%
sns.boxplot(y=tips['tip'])
#in y axis

# %%
sns.boxplot(y='tip',data=tips)

# %% [markdown]
# ### Count Plot:

# %%
sns.countplot(tips['day'])

# %% [markdown]
# ### Distributions:

# %%
sns.distplot(tips['total_bill'],kde=False)
#kde->

# %%
sns.distplot(tips['total_bill'],hist=False)
#hist->

# %%
sns.distplot(tips['total_bill'],kde=False,rug=True)
#rug->

# %%
sns.distplot(tips['total_bill'],rug=True)

# %% [markdown]
# ### Joint Plot:

# %%
sns.jointplot("total_bill","tip",data=tips)

# %%
sns.jointplot("total_bill","tip",data=tips,kind='kde')

# %%
tips.dtypes!='category'
# Out:
# total_bill     True
# tip            True
# sex           False
# smoker        False
# day           False
# time          False
# size           True
# dtype: bool

# %%
num_col=tips.columns[tips.dtypes!='category']

# %%
#Getting combinations
val=1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        plt.subplot(3,3,val)
        plt.scatter(tips[num_col[i]],tips[num_col[j]])
        plt.title(num_col[i]+" "+num_col[j])
        val+=1

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="smoker")

# %%
sns.pairplot(tips,hue="sex",kind="reg")

# %%
sns.regplot("tip","total_bill",data=tips)

# %% [markdown]
# ### Heat Map:

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %% [markdown]
# ### Style:

# %%
sns.set(style='whitegrid')
sns.regplot("tip","total_bill",data=tips)
